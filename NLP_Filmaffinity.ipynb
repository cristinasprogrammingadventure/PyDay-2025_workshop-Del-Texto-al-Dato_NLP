# %% [markdown]
# # **Del texto al dato: cómo entienden las máquinas el lenguaje con Python (reseñas de películas - *Filmaffinity*)**
#
# Este cuaderno es el material del taller del PyDay 2025.
# Aquí aprenderemos cómo convertir texto en datos medibles, cómo analizar palabras, cómo extraer información útil y cómo los algoritmos estiman el tono o contenido de un texto.
#
# Usaremos herramientas ampliamente utilizadas en el análisis de lenguaje: **NLTK**, **VADER**, **spaCy**, **TextBlob**, **matplotlib** y **WordCloud**.
#
# https://github.com/cristinasprogrammingadventure/PyDay-2025_workshop-Del-Texto-al-Dato_NLP

# %% [markdown]
# ## ¿Qué vamos a aprender?
#
# Las máquinas no entienden el lenguaje como los humanos: **detectan patrones, relaciones y señales numéricas**.
# En este taller veremos paso a paso cómo convertir texto en datos, cómo visualizarlo y cómo analizar su sentimiento.
#
# Estas son las tareas que realizaremos:
#
# 1. Cargar texto y limpiarlo.
# 2. Tokenización: convertir texto en palabras individuales.
# 3. Eliminar puntuación y stopwords.
# 4. Obtener frecuencias de palabras y ver las más comunes.
# 5. Crear nubes de palabras.
# 6. Hacer análisis de sentimiento (TextBlob, VADER, pysentimiento, etc).
# 7. Visualizar sentimientos con gráficos.
# 8. Introducción a spaCy (POS tagging, entidades).
# 9. Comparación entre textos.
# 10. Conclusiones y limitaciones del análisis automático.

# %% [markdown]
# ## Textos y librerías
#
# Las librerías que podemos usar:
#
# - **NLTK**: tokenización y stopwords.
# - **spaCy**: análisis estructural del lenguaje (si da tiempo)
# - **TextBlob**: análisis de sentimiento simple.
# - **VADER**: análisis de sentimiento optimizado para redes sociales.
# - **matplotlib**: visualización.
# - **WordCloud**: nubes de palabras.
#
# A continuación cargaremos las librerías y empezaremos con los textos.

# %% [markdown]
# ## Primer bloque de código didáctico (carga de textos + tokenización)

# %%
# ==== LIBRERÍAS BÁSICAS ====

import pandas as pd        # manejo de datos en tablas (DataFrames)
import numpy as np         # cálculos numéricos y arrays
import re
import string
from collections import Counter

# ==== LIBRERÍAS DE PROCESAMIENTO DE TEXTO ====

# Para análisis de sentimiento y corrección gramatical
from textblob import TextBlob

# Para visualización
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Descargar recursos necesarios de NLTK
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('punkt')
nltk.download("punkt_tab") # para tokenización en español
nltk.download('stopwords')
nltk.download('vader_lexicon')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
stopwords_es = stopwords.words("spanish") # Stopwords en español
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %% [markdown]
# ### **Textos a analizar (creando un objeto)**
#
# - Escribirlos directamente entre comillas
# - Cargarlos desde un fichero .txt, .csv
# - Cargarlos desde una URL
# - Cargarlo haciendo *web scraping*

# %%
# Texto escrito directamente entre comillas

# https://www.filmaffinity.com/es/user/rating/447567/194845.html

texto1 = """
Una película hecha con el corazón y las entrañas, una experiencia honesta y donde desde la vulnerabilidad surfeamos entre la tragedia y la comedia,
para poder comprender desde cerca lo que puede significar ser una madre/padre con una persona dependiente en 2025.
Dirección, actuación, fotografía excelentes, el guión surfea de forma frenética entre aventuras y desventuras,
me la vería de nuevo y no es algo que diga a menudo, muchas gracias Mary y Rosa.
"""

# https://www.filmaffinity.com/es/user/rating/111174/284233.html
texto2 = """
Comedieta bienintencionada y sorprendentemente entretenida a pesar de ser comedia romántica, género del que suelo huir despavorido si se me presenta la ocasión.
Todo gira en torno a una chica (Melissa Barrera) que tiene una relación con un chico (Edmund Donovan) que al final no sale como esperaba.
A partir de ahí, descubre en el armario de su casa a un inesperado habitante, un sucedáneo moderno de Bestia de “La Bella y la Bestia” al que la chica, en un alarde de creatividad, llama Monstruo (Tommy Dewey).
El previsible susto inicial se va tornando en escepticismo y acaba deviniendo en confianza.
Caroline Lindy compensa la predictibilidad del guion con un buen sentido del ritmo. Además, conjuga teatro y musical de una forma acertada,
logrando que la historia acabe atrapándote de una forma que yo, por lo menos, no esperaba. Al final, muy en el fondo de su enfoque superficial,
descansa un relato de autodescubrimiento con monstruo en el armario como trasfondo argumental, que al fin y al cabo es tanto físico como metafórico.
A destacar la buena actuación de Melissa Barrera.
"""

# %% [markdown]
# ### **Tokenización básica**

# %%
def limpiar_y_tokenizar(texto):
    texto = texto.lower()
    texto = re.sub(r"[^\wáéíóúüñ]+", " ", texto)
    tokens = word_tokenize(texto, language="spanish")
    tokens = [t for t in tokens if t not in stopwords_es and t not in string.punctuation]
    return tokens

tokens1 = limpiar_y_tokenizar(texto1)
tokens2 = limpiar_y_tokenizar(texto2)

tokens1, tokens2
# Out:
# (['película',
#   'hecha',
#   'corazón',
#   'entrañas',
#   'experiencia',
#   'honesta',
#   'vulnerabilidad',
#   'surfeamos',
#   'tragedia',
#   'comedia',
#   'poder',
#   'comprender',
#   'cerca',
#   'puede',
#   'significar',
#   'ser',
#   'madre',
#   'padre',
#   'persona',
#   'dependiente',
#   '2025',
#   'dirección',
#   'actuación',
#   'fotografía',
#   'excelentes',
#   'guión',
#   'surfea',
#   'forma',
#   'frenética',
#   'aventuras',
#   'desventuras',
#   'vería',
#   'nuevo',
#   'diga',
#   'menudo',
#   'muchas',
#   'gracias',
#   'mary',
#   'rosa'],
#  ['comedieta',
#   'bienintencionada',
#   'sorprendentemente',
#   'entretenida',
#   'pesar',
#   'ser',
#   'comedia',
#   'romántica',
#   'género',
#   'suelo',
#   'huir',
#   'despavorido',
#   'si',
#   'presenta',
#   'ocasión',
#   'gira',
#   'torno',
#   'chica',
#   'melissa',
#   'barrera',
#   'relación',
#   'chico',
#   'edmund',
#   'donovan',
#   'final',
#   'sale',
#   'esperaba',
#   'partir',
#   'ahí',
#   'descubre',
#   'armario',
#   'casa',
#   'inesperado',
#   'habitante',
#   'sucedáneo',
#   'moderno',
#   'bestia',
#   'bella',
#   'bestia',
#   'chica',
#   'alarde',
#   'creatividad',
#   'llama',
#   'monstruo',
#   'tommy',
#   'dewey',
#   'previsible',
#   'susto',
#   'inicial',
#   'va',
#   'tornando',
#   'escepticismo',
#   'acaba',
#   'deviniendo',
#   'confianza',
#   'caroline',
#   'lindy',
#   'compensa',
#   'predictibilidad',
#   'guion',
#   'buen',
#   'ritmo',
#   'además',
#   'conjuga',
#   'teatro',
#   'musical',
#   'forma',
#   'acertada',
#   'logrando',
#   'historia',
#   'acabe',
#   'atrapándote',
#   'forma',
#   'menos',
#   'esperaba',
#   'final',
#   'fondo',
#   'enfoque',
#   'superficial',
#   'descansa',
#   'relato',
#   'autodescubrimiento',
#   'monstruo',
#   'armario',
#   'trasfondo',
#   'argumental',
#   'fin',
#   'cabo',
#   'físico',
#   'metafórico',
#   'destacar',
#   'buena',
#   'actuación',
#   'melissa',
#   'barrera'])

# %% [markdown]
# ### Obtener la **frecuencia** de cada *palabra / token* con el ***Counter***

# %%
# si no se hizo en el prncipio, se debería escribir ahora el código -> "from collections import Counter"
# Llamamos al contador de palabras 'Counter'

def frecuencia_palabras(tokens):
    return Counter(tokens)

freq1 = frecuencia_palabras(tokens1)
freq2 = frecuencia_palabras(tokens2)

freq1.most_common(10), freq2.most_common(10)
# Out:
# ([('película', 1),
#   ('hecha', 1),
#   ('corazón', 1),
#   ('entrañas', 1),
#   ('experiencia', 1),
#   ('honesta', 1),
#   ('vulnerabilidad', 1),
#   ('surfeamos', 1),
#   ('tragedia', 1),
#   ('comedia', 1)],
#  [('chica', 2),
#   ('melissa', 2),
#   ('barrera', 2),
#   ('final', 2),
#   ('esperaba', 2),
#   ('armario', 2),
#   ('bestia', 2),
#   ('monstruo', 2),
#   ('forma', 2),
#   ('comedieta', 1)])

# %% [markdown]
# ### Visualización simple de **frecuencias**

# %%
# Llamamos al contador de palabras 'Counter' através de una función

def plot_frecuencias(counter, titulo):
    palabras, frecs = zip(*counter.most_common(20))
    plt.figure(figsize=(8,4))
    plt.bar(palabras, frecs)
    plt.title(titulo)
    plt.xticks(rotation=45)
    plt.show()

plot_frecuencias(freq1, "Top palabras texto 1")
plot_frecuencias(freq2, "Top palabras texto 2")

# %% [markdown]
# ### ***WordCloud*** para cada texto

# %%
def generar_wordcloud(texto, titulo):
    wc = WordCloud(width=800, height=400, background_color="white").generate(texto)
    plt.figure(figsize=(10,5))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.title(titulo)
    plt.show()

generar_wordcloud(texto1, "WordCloud - texto 1")

# %%
generar_wordcloud(texto2, "WordCloud - texto 2")

# %% [markdown]
# Observaciones:
#
# - WordCloud **tiene stopwords** porque estás usando el **texto original**
#
# - El WordCloud no sabe qué es una stopword, a menos que se las pasemos nosotros.
#
# Solución:
# - crear WordCloud sin stopwords, así:

# %%
from wordcloud import WordCloud, STOPWORDS

stopwords_wc = set(STOPWORDS) | set(stopwords_es)

def generar_wordcloud_sin_stopwords(texto, titulo):
    wc = WordCloud(
        width=800,
        height=400,
        background_color="white",
        stopwords=stopwords_wc
    ).generate(texto)

    plt.figure(figsize=(10,5))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.title(titulo)
    plt.show()

generar_wordcloud_sin_stopwords(texto1, "WordCloud sin stopwords - texto 1 - Reseña de la peli americana 'Si pudiera, te daría una patada', ")

# %%
generar_wordcloud_sin_stopwords(texto2, "WordCloud sin stopwords - texto 2 - Reseña de la peli inglesa 'Amor a lo bestia', ")

# %% [markdown]
# ### Análisis de sentimiento con ***TextBlob***

# %%
def sentimiento_textblob(texto):
    blob = TextBlob(texto)
    return blob.sentiment.polarity

print("Sentimiento texto 1 - Reseña de la peli americana 'Si pudiera, te daría una patada':", sentimiento_textblob(texto1))
print("Sentimiento texto 2 - Reseña de la peli inglesa 'Amor a lo bestia':", sentimiento_textblob(texto2))
# Out:
# Sentimiento texto 1 - Reseña de la peli americana 'Si pudiera, te daría una patada': 0.0
# Sentimiento texto 2 - Reseña de la peli inglesa 'Amor a lo bestia': 0.0

# %% [markdown]
# Observaciones:
#
# - TextBlob no sirve para español.
#
# - TextBlob solo tiene un modelo de sentimiento para inglés, no para español, y devuelve valores absurdos

# %% [markdown]
# ### Análisis de sentimiento con ***VADER***

# %%
sia = SentimentIntensityAnalyzer()

sent1 = sia.polarity_scores(texto1)
sent2 = sia.polarity_scores(texto2)

sent1, sent2
# Out:
# ({'neg': 0.032, 'neu': 0.968, 'pos': 0.0, 'compound': -0.296},
#  {'neg': 0.025, 'neu': 0.975, 'pos': 0.0, 'compound': -0.5267})

# %% [markdown]
# ### Visualización del sentimiento analizado con Vader

# %%
def plot_sentiment_vader(scores, titulo):
    labels = list(scores.keys())
    vals = list(scores.values())
    plt.figure(figsize=(6,3))
    plt.bar(labels, vals)
    plt.title(titulo)
    plt.show()

plot_sentiment_vader(sent1, "Sentimiento VADER - Texto 1 - Reseña de la peli americana 'Si pudiera, te daría una patada'")
plot_sentiment_vader(sent2, "Sentimiento VADER - Texto 2 - Reseña de la peli inglesa 'Amor a lo bestia'")

# %% [markdown]
# Observaciones reseñas *Filmaffinity*:
#
# - texto positivo  (opinión película americana) → compound -0.296   (resultado 'UN POCO NEGATIVO' -> incorrecto)
#
# - texto ambivalente con partes positivas  (opinión película inglesa) → compound -0.5267     (resultado 'BASTANTE NEGATIVO' -> incorrecto)
#
# Causas:
#
# - VADER no funciona bien en español ya que está diseñado para inglés.
# - El lexicón contiene ~7.500 palabras solo con carga emocional.
# - Palabras neutras y muchas subjetivas NO aparecen.
# - En español casi nada coincide, por eso da NO ENCONTRADA.

# %%
# CÓDIGO PARA VER PUNTUACIÓN PALABRA POR PALABRA con VADER

import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

palabras = [
    "excelente", "excellent", "larga", "long",
    "servicio", "service", "atento", "attentive",
    "terrible", "deliciosa", "delicious", "delic",
    "mala", "bad", "fría", "cold",
    "decepcionante", "disappointing",
    "pero", "but"
]

for p in palabras:
    if p in analyzer.lexicon:
        print(f"{p:15} → {analyzer.lexicon[p]}")
    else:
        print(f"{p:15} → NO ENCONTRADA EN EL LEXICON")
# Out:
# excelente       → NO ENCONTRADA EN EL LEXICON
# excellent       → 2.7
# larga           → NO ENCONTRADA EN EL LEXICON
# long            → NO ENCONTRADA EN EL LEXICON
# servicio        → NO ENCONTRADA EN EL LEXICON
# service         → NO ENCONTRADA EN EL LEXICON
# atento          → NO ENCONTRADA EN EL LEXICON
# attentive       → NO ENCONTRADA EN EL LEXICON
# terrible        → -2.1
# deliciosa       → NO ENCONTRADA EN EL LEXICON
# delicious       → 2.7
# delic           → NO ENCONTRADA EN EL LEXICON
# mala            → NO ENCONTRADA EN EL LEXICON
# bad             → -2.5
# fría            → NO ENCONTRADA EN EL LEXICON
# cold            → NO ENCONTRADA EN EL LEXICON
# decepcionante   → NO ENCONTRADA EN EL LEXICON
# disappointing   → -2.2
# pero            → NO ENCONTRADA EN EL LEXICON
# but             → NO ENCONTRADA EN EL LEXICON
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# **Soluciones posibles**:
#
# ✔ Opción A : Usar VADER en textos traducidos al inglés
#
# - Luego aplicar VADER sobre el texto traducido.
# - Rápido ya que no requiere entrenamiento
#
# ✔✔ Opción B — Usar un modelo de sentimiento para español
#
#
# - HuggingFace sentiment-es (modelo entrenado en español)
#
# - nlptown/bert-base-multilingual-sentiment
#
# - pysentimiento (RobBERT, BERTin, BETO (modelos finetuned))

# %% [markdown]
# ## Analizar de textos con ***pysentimiento***
#
# Cómo funciona pysentimiento (explicación para tu taller)
#
# pysentimiento es un modelo basado en BERT multilingüe (a veces “BETO” para español) ya entrenado para reconocer sentimiento en español.
#
# ✔️ ¿Qué analiza el modelo?
#
# Analiza:
#
# las palabras
#
# sus relaciones sintácticas
#
# su contexto entero (antes y después)
#
# patrones de uso típicos en reseñas y comentarios
#
# Es decir:
# no usa diccionarios positivos/negativos como VADER,
# sino que reconoce patrones gracias a haber sido entrenado con miles de ejemplos reales.
#
# ✔️ Qué devuelve
#
# Cuando le das un texto, devuelve:
#
# output = etiqueta final (POS / NEU / NEG)
# probas = {probabilidad de POS, NEU, NEG}
#
#
# Ejemplo:
#
# AnalyzerOutput(output=POS,
#                probas={POS: 0.981, NEU: 0.017, NEG: 0.002})
#
# ✔️ No devuelve un valor 'compound'
#
# Porque eso es una creación específica de VADER, no un concepto general.
# En modelos de clasificación moderna como BERT:
#
# la predicción final = la clase con mayor probabilidad
#
# la “intensidad” = las probabilidades mismas
# (p. ej. POS=0.98 → muy positivo)

# %%
# Ejemplo con pysentimiento e instalación de esta librería:

# !pip install pysentimiento
from pysentimiento import create_analyzer
# Out:
# Collecting pysentimiento
#   Downloading pysentimiento-0.7.3-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: accelerate>=0.27.2 in /usr/local/lib/python3.12/dist-packages (from pysentimiento) (1.12.0)
# Requirement already satisfied: datasets>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pysentimiento) (4.0.0)
# Collecting emoji>=1.6.1 (from pysentimiento)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: spacy>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from pysentimiento) (3.8.11)
# Requirement already satisfied: torch!=2.0.1,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pysentimiento) (2.9.0+cu126)
# Requirement already satisfied: transformers>=4.13.0 in /usr/local/lib/python3.12/dist-packages (from pysentimiento) (4.57.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.27.2->pysentimiento) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.27.2->pysentimiento) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.27.2->pysentimiento) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.27.2->pysentimiento) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.27.2->pysentimiento) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.27.2->pysentimiento) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.1->pysentimiento) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.1->pysentimiento) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.1->pysentimiento) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.1->pysentimiento) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.1->pysentimiento) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.1->pysentimiento) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.1->pysentimiento) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.1->pysentimiento) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (2025.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (0.20.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy>=3.5.0->pysentimiento) (75.2.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (3.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.13.0->pysentimiento) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.13.0->pysentimiento) (0.22.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (3.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=0.27.2->pysentimiento) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.5.0->pysentimiento) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.5.0->pysentimiento) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.5.0->pysentimiento) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.10.1->pysentimiento) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.10.1->pysentimiento) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.10.1->pysentimiento) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.10.1->pysentimiento) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch!=2.0.1,>=2.0.0->pysentimiento) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.5.0->pysentimiento) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.5.0->pysentimiento) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy>=3.5.0->pysentimiento) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.5.0->pysentimiento) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.5.0->pysentimiento) (7.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy>=3.5.0->pysentimiento) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.10.1->pysentimiento) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.10.1->pysentimiento) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.10.1->pysentimiento) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.10.1->pysentimiento) (1.17.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=3.5.0->pysentimiento) (2.0.1)
# Downloading pysentimiento-0.7.3-py3-none-any.whl (39 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 39.0 MB/s eta 0:00:00
# Installing collected packages: emoji, pysentimiento
# Successfully installed emoji-2.15.0 pysentimiento-0.7.3

# %%
analyzer = create_analyzer(task="sentiment", lang="es")
print(analyzer.predict(texto1))
print(analyzer.predict(texto2))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/925 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/435M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# AnalyzerOutput(output=POS, probas={POS: 0.950, NEU: 0.045, NEG: 0.005})
# AnalyzerOutput(output=POS, probas={POS: 0.482, NEU: 0.478, NEG: 0.040})

# %%
res1 = analyzer.predict(texto1)
res2 = analyzer.predict(texto2)

res1, res2
# Out:
# (AnalyzerOutput(output=POS, probas={POS: 0.950, NEU: 0.045, NEG: 0.005}),
#  AnalyzerOutput(output=POS, probas={POS: 0.482, NEU: 0.478, NEG: 0.040}))

# %% [markdown]
# Observaciones / resultados:
#
# - texto1 -> POS: , NEU: , NEG:
#
# - texto2 -> NEG: , NEU: , POS:

# %% [markdown]
# ### Gráfico de barras comparando probabilidades de sentimiento

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ["POS", "NEU", "NEG"]

probs1 = [res1.probas["POS"], res1.probas["NEU"], res1.probas["NEG"]]
probs2 = [res2.probas["POS"], res2.probas["NEU"], res2.probas["NEG"]]

x = np.arange(len(labels))  # posiciones
width = 0.35

plt.figure(figsize=(8,5))
plt.bar(x - width/2, probs1, width, label='Texto 1')
plt.bar(x + width/2, probs2, width, label='Texto 2')

plt.xticks(x, labels)
plt.ylabel("Probabilidad")
plt.title("Comparación de sentimiento (pysentimiento)")
plt.legend()
plt.ylim(0,1)

plt.show()

# %% [markdown]
# ### Pie charts de cada texto

# %%
def pie_sentimiento(result, titulo):
    labels = ["POS", "NEU", "NEG"]
    sizes = [result.probas["POS"], result.probas["NEU"], result.probas["NEG"]]

    plt.figure(figsize=(5,5))
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title(titulo)
    plt.axis('equal')
    plt.show()

pie_sentimiento(res1, "Sentimiento – Texto 1")
pie_sentimiento(res2, "Sentimiento – Texto 2")

# %% [markdown]
# ### # Pie Chart doble personalizado, más visual
#
# - con colores específicos y 30% de transparencia (alpha=0.3)
# - Cada radar chart por separado como figuras independientes.
#
#     POS → verde bosque
#
#     NEU → azul claro
#
#     NEG → rojo burdeos

# %%
# Los colores (forestgreen, lightskyblue, darkred) de tipo "semáforo"
colores = {
    "POS": "forestgreen",
    "NEU": "lightskyblue",
    "NEG": "darkred"
}

def pie_sentimiento_doble(result1, result2, titles=("Texto 1", "Texto 2")):
    labels = ["POS", "NEU", "NEG"]

    sizes1 = [result1.probas[l] for l in labels]
    sizes2 = [result2.probas[l] for l in labels]

    # Crear figura con 2 gráficos lado a lado
    fig, axes = plt.subplots(1, 2, figsize=(14,6))

    # -------- PIE 1 --------
    wedges1, texts1, autotexts1 = axes[0].pie(
        sizes1,
        labels=labels,
        colors=[colores[l] for l in labels],
        autopct=lambda pct: f"{pct:.1f}%",
        startangle=140,
        wedgeprops={'alpha': 0.7}  # % de transparencia
    )
    axes[0].set_title(titles[0])
    axes[0].axis('equal')

    # Leyenda externa
    axes[0].legend(wedges1, labels, title="Sentimiento", loc="upper right", bbox_to_anchor=(1.3, 1))

    # -------- PIE 2 --------
    wedges2, texts2, autotexts2 = axes[1].pie(
        sizes2,
        labels=labels,
        colors=[colores[l] for l in labels],
        autopct=lambda pct: f"{pct:.1f}%",
        startangle=140,
        wedgeprops={'alpha': 0.7}
    )
    axes[1].set_title(titles[1])
    axes[1].axis('equal')

    axes[1].legend(wedges2, labels, title="Sentimiento", loc="upper right", bbox_to_anchor=(1.3, 1))

    plt.tight_layout()
    plt.show()


# --- Llamar función ---
pie_sentimiento_doble(res1, res2, titles=("Sentimiento – Texto 1", "Sentimiento – Texto 2"))

# %% [markdown]
# ### Radar Chart (para comparación multiclase)
#
# Aquí de momento sólo tenems 3 clases / criterios analizados : "POS", "NEU", "NEG"

# %%
import matplotlib.pyplot as plt
import numpy as np

def radar_chart(res1, res2, labels=["POS", "NEU", "NEG"]):
    # Probabilidades
    probs1 = [res1.probas[l] for l in labels]
    probs2 = [res2.probas[l] for l in labels]

    # Cerrar el círculo
    probs1 += probs1[:1]
    probs2 += probs2[:1]

    # Ángulos
    angles = np.linspace(0, 2 * np.pi, len(labels) + 1)

    # Radar
    fig, ax = plt.subplots(figsize=(6,6), subplot_kw={"polar": True})

    ax.plot(angles, probs1, linewidth=2)
    ax.fill(angles, probs1, alpha=0.25)

    ax.plot(angles, probs2, linewidth=2)
    ax.fill(angles, probs2, alpha=0.25)

    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(labels)

    ax.set_ylim(0, 1)
    ax.set_title("Radar Chart – Comparación de sentimiento (pysentimiento)")

    plt.legend(["Texto 1", "Texto 2"], loc="upper right", bbox_to_anchor=(1.3, 1.1))
    plt.show()

radar_chart(res1, res2)

# %%
# Mismos colores que en el radar
# (no haría falta redefinirlos !)

colores = {
    "POS": "forestgreen",
    "NEU": "lightskyblue",
    "NEG": "darkred"
}

def radar_chart_doble(result1, result2, titles=("Texto 1", "Texto 2"), labels=["POS", "NEU", "NEG"]):
    # Preparación de datos
    probs1 = [result1.probas[l] for l in labels] + [result1.probas[labels[0]]]
    probs2 = [result2.probas[l] for l in labels] + [result2.probas[labels[0]]]

    angles = np.linspace(0, 2*np.pi, len(labels) + 1)

    fig, axes = plt.subplots(1, 2, figsize=(14,6), subplot_kw=dict(polar=True))

    # --- Gráfico 1 ---
    ax = axes[0]
    color1 = colores[result1.output]

    ax.plot(angles, probs1, linewidth=2, color=color1)
    ax.fill(angles, probs1, alpha=0.3, color=color1)

    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(labels, fontsize=12)
    ax.set_ylim(0, 1)
    ax.set_title(titles[0], fontsize=14, pad=20)

    # --- Gráfico 2 ---
    ax = axes[1]
    color2 = colores[result2.output]

    ax.plot(angles, probs2, linewidth=2, color=color2)
    ax.fill(angles, probs2, alpha=0.3, color=color2)

    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(labels, fontsize=12)
    ax.set_ylim(0, 1)
    ax.set_title(titles[1], fontsize=14, pad=20)

    plt.tight_layout()
    plt.show()


# --- Llamar función ---
radar_chart_doble(res1, res2, titles=("Radar – Texto 1", "Radar – Texto 2"))

# %% [markdown]
# ## Conclusiones
#
# Hemos visto cómo convertir texto en datos, cómo limpiarlo, visualizarlo y analizar su sentimiento.
# También vimos cómo las máquinas interpretan la estructura del lenguaje con herramientas como spaCy.
#
# Este cuaderno muestra un flujo completo básico para análisis exploratorio de texto:
# desde tokenización y frecuencias hasta sentimiento y relaciones entre textos.
#
# Estos métodos son útiles para:
# - reseñas
# - encuestas abiertas
# - análisis de redes sociales
# - análisis de artículos o noticias
# - comparaciones entre documentos
